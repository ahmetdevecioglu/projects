# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('survey_results_public.csv')
df_schema = pd.read_csv('survey_results_schema.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc  ... SurveyEase SurveyLength  \
# ...

# %%
pd.set_option('display.max_columns', 61)
#pd.set_option('display.max_rows', 64661)

# %%
notlar = {
    'sinav_donem': ['1.sinav', '2.sinav', '3.sinav']
    'ayse':[80, 90, 100],
    'ali': [40, 90, 50],
    'caglar': [60, 40, 78],
}

notlar
# Out:
#   File "<ipython-input-10-4769b8ff669d>", line 3
#     'ayse':[80, 90, 100],
#          ^
# SyntaxError: invalid syntax

# %%
df_notlar = pd.DataFrame(notlar)

df_notlar

# %%
df_notlar['ayse']

# %%
type(df_notlar['ayse'])

# %%
df_notlar[['ayse', 'caglar']]

# %%
df_notlar.iloc[[1,2],2]

# %%
df_notlar.loc[[1,2],['caglar','ali']] = 40

# %%
df_notlar

# %%
df_notlar['ali'] + df_notlar['ayse']

# %%
df_notlar.iloc[0:2, 0:2]

# %%
df_schema

# %%
df_schema.columns

# %%
df_schema.info()

# %%
df_schema.info

# %%
df_schema.columns

# %%
df_schema['QuestionText']

# %%
df_schema.iloc[[45], [1]]

# %%
df_schema.iloc[45, 1]

# %%
df.iloc[3:6, 6:8]

# %%
df

# %%
notlar_yeni = {
    'sinav_donem': ['1.sinav', '2.sinav', '3.sinav'],
    'ayse':[80, 90, 100],
    'ali': [40, 90, 50],
    'caglar': [60, 40, 78],
}

notlar_yeni

# %%
df_notlar_yeni = pd.DataFrame(notlar_yeni)\

df_notlar_yeni

# %%
kume = {1,2}

kume

# %%
kume.add(10)

kume

# %%
liste = [1,2,3,4,5,6]
liste.extend([[8]])
liste.append(10)

liste

# %%
df_econ = pd.read_csv('Variables1.csv')

df_econ
# Out:
#     Years           GDP  Interest       Savings       Capital
# 0    1990  1.506763e+11     62.72  3.082614e+10  3.698993e+10
# 1    1991  1.500278e+11     59.87  2.547388e+10  3.407438e+10
# 2    1992  1.584591e+11     67.77  2.779625e+10  3.701965e+10
# 3    1993  1.801697e+11     69.63  3.245352e+10  4.795327e+10
# 4    1994  1.306902e+11     92.04  2.402735e+10  2.786384e+10
# 5    1995  1.694859e+11    106.31  3.203734e+10  4.317410e+10
# 6    1996  1.814756e+11     73.99  3.839270e+10  4.455464e+10
# 7    1997  1.898346e+11     78.04  3.740410e+10  4.766897e+10
# 8    1998  2.757687e+11     78.97  6.816709e+10  6.578907e+10
# 9    1999  2.558843e+11     69.97  5.398080e+10  5.461002e+10
# 10   2000  2.729794e+11    183.20  5.649884e+10  6.496954e+10
# 11   2001  2.002519e+11     59.00  4.384011e+10  3.631663e+10
# 12   2002  2.384281e+11     44.00  5.413274e+10  5.064966e+10
# 13   2003  3.118230e+11     26.00  6.660012e+10  7.007759e+10
# ...

# %%
df_econ.loc[[25], 'GDP']

# %%
df_econ.set_index('Years', inplace = True)

# %%
df_econ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-13f702b3c05f> in <module>
# ----> 1 df_econ
#
# NameError: name 'df_econ' is not defined

# %%
df_econ.loc[[2012], ['Capital', 'Savings']]

# %%
g = df_econ[['GDP', 'Capital', 'Savings']]

plt.plot(g)

# %%
df_econ.info()

# %%
y = df_econ['Interest']

plt.plot(y)

# %%
df['Respondent']

# %%
df.iloc[[0], :]

# %%
new = df.loc[3, 'Country']

# %%
new

# %%
df.index.value_counts('CompTotal')

# %%
new_df = df.set_index('Country')
new_df

# %%
new_df.loc['Turkey']

# %%
new_df.reset_index()
new_df

# %%
new_df.set_index('Respondent', inplace = True)

# %%
new_df

# %%
new_df.sort_index(ascending = False, inplace = True)

# %%
new_df

# %%
new_df.drop(['index'], axis = 1)

# %%
new_df.drop(['index'], axis = 1)

# %%
df_econ['Interest'] > 40
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# Name: Interest, dtype: bool

# %%
df_econ['Years'] == 2002
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# Name: Years, dtype: bool

# %%
nc = df['Country'] == 'Germany'

#df.loc[nc, 'email']
df[~nc] # df[nc] tersi

#filt = df['Country'] == 'Turkey' & df['CompTotal'] > 1500
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 6               7                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df[nc].head()
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0            1  I am a developer by profession      Yes   NaN         13
# 5            6  I am a developer by profession       No   NaN         14
# 22          23  I am a developer by profession      Yes  27.0         14
# 23          24  I am a developer by profession      Yes  45.0         14
# 33          34  I am a developer by profession      Yes  29.0         15
#
#    CompFreq  CompTotal  ConvertedComp  Country   CurrencyDesc CurrencySymbol  \
# 0   Monthly        NaN            NaN  Germany  European Euro            EUR
# 5       NaN        NaN            NaN  Germany  European Euro            EUR
# 22      NaN        NaN            NaN  Germany  European Euro            EUR
# 23   Yearly    85000.0        91883.0  Germany  European Euro            EUR
# 33      NaN        NaN            NaN  Germany            NaN            NaN
#
# ...

# %%
df[~nc].head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 6           7                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
# 6   NaN         18  Monthly        NaN            NaN               India
#
#            CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
high_salary = (df['ConvertedComp'] > 100000) & (df['Age'] > 18)

# %%
high_salary
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Length: 64461, dtype: bool

# %%
nn = df.loc[high_salary]

# %%
#len(nn)
nn
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 7               8  I am a developer by profession      Yes  36.0         12
# 15             16  I am a developer by profession      Yes  45.0          8
# 17             18  I am a developer by profession      Yes  32.0         12
# 41             42  I am a developer by profession       No  32.0         14
# 47             48  I am a developer by profession       No  38.0         30
# ...           ...                             ...      ...   ...        ...
# 61636       62886  I am a developer by profession      Yes  32.0         24
# 61641       62891  I am a developer by profession      Yes  30.0         15
# 61658       62908  I am a developer by profession      Yes  43.0          6
# 62016       63311  I am a developer by profession      Yes  27.0         16
# 62054       63350  I am a developer by profession      Yes  30.0         19
#
# ...

# %%
df.loc[high_salary, ['Country', 'Age']]
# Out:
#               Country   Age
# 7       United States  36.0
# 15     United Kingdom  45.0
# 17      United States  32.0
# 41      United States  32.0
# 47      United States  38.0
# ...               ...   ...
# 61636   United States  32.0
# 61641   United States  30.0
# 61658   United States  43.0
# 62016          Brazil  27.0
# 62054          Canada  30.0
#
# [6933 rows x 2 columns]

# %%
df.loc[high_salary]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-70d927d2b605> in <module>
# ----> 1 df.loc[high_salary, ['Country'] == Turkey]
#
# NameError: name 'Turkey' is not defined

# %%
countries = ['Turkey', 'India', 'Brazil']
new_filt = df['Country'].isin(countries)
df.loc[new_filt, ['Country']]
# Out:
#       Country
# 6       India
# 21      India
# 43     Brazil
# 57      India
# 58     Brazil
# ...       ...
# 64408  Brazil
# 64427  Brazil
# 64439   India
# 64442   India
# 64452   India
#
# [10998 rows x 1 columns]

# %%
cool_filt = df['LanguageWorkedWith'].str.contains('Python', na = False)

nn_df = df.loc[cool_filt, ['LanguageWorkedWith']]

# %%
nn_df.iloc[[64446], [0]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-366e127cbba8> in <module>
# ----> 1 nn_df.iloc[[64446], [0]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
# ...

# %%
nn_df
# Out:
#                                       LanguageWorkedWith
# 2                               Objective-C;Python;Swift
# 7                                             Python;SQL
# 9                    HTML/CSS;Java;JavaScript;Python;SQL
# 12                                   C;JavaScript;Python
# 14      Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# ...                                                  ...
# 64433  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 64438     C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 64443            C++;HTML/CSS;Java;JavaScript;Python;SQL
# 64446  Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
#
# [25287 rows x 1 columns]

# %%
nn_df.iloc[0, 1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-344f05f2c0cf> in <module>
# ----> 1 nn_df.iloc[0, 1]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
# ...

# %%
def greet(who="Colin"):
    return "Hello,", who
    
greet()
greet(who="Kaggle")
# (In this case, we don't need to specify the name of the argument, because it's unambiguous.)
greet("world")
# Out:
# ('Hello,', 'world')

# %%
def greet(who="Colin"):
    print("Hello,", who)
    
greet()
greet(who="Kaggle")
# (In this case, we don't need to specify the name of the argument, because it's unambiguous.)
greet("world")
# Out:
# Hello, Colin
# Hello, Kaggle
# Hello, world

# %%
df_y = (df['Country'] == 'Turkey') & (df['Age'] < 18)

# %%
df.loc[df_y]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 2131         2140  I am a student who is learning to code      Yes  15.0
# 8500         8532  I am a student who is learning to code      Yes  13.0
# 10098       10131             I code primarily as a hobby      Yes  14.0
# 12525       12564          I am a developer by profession      Yes  17.0
# 12663       12703  I am a student who is learning to code      Yes  17.0
# 14416       14461             I code primarily as a hobby      Yes  12.0
# 19945       20025             I code primarily as a hobby      Yes  17.0
# 22814       22902  I am a student who is learning to code      Yes  17.0
# 28052       28156  I am a student who is learning to code      Yes  15.0
# 28988       29097  I am a student who is learning to code      Yes  17.0
# 43329       44152             I code primarily as a hobby      Yes  13.0
# 50843       51896             I code primarily as a hobby      Yes  13.0
# ...

# %%
yas = 18
ad = 'ali'

if yas == 18 and ad == 'ali':
    print("aa")
else:
    print("nn")
# Out:
# aa
